# %% [markdown]
# # Model $G_\alpha$

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
from model_alpha import model_alpha_synthetic_generator
from model_beta import model_beta_synthetic_generator

# %%
pd.set_option('display.max_columns', None)  # or 1000

# %% [markdown]
# ### Load data

# %%
choices_df = pd.read_excel('data/2021.xlsx', sheet_name='Resultaten')
schools_df = pd.read_excel('data/2021.xlsx', sheet_name='Klassen')

# %%
choices_df.head()
# Out:
#   Basisschool advies  Lotnummer        Geplaatst op Positie  \
# 0        vmbo-t/havo       7389      Niet geplaatst       -
# 1             vmbo-b       7742      Niet geplaatst       -
# 2               havo        129  Alasca - v.a. havo       1
# 3           havo/vwo       7606  Alasca - v.a. havo       1
# 4           havo/vwo        109  Alasca - v.a. havo       2
#
#   Voorrang/Hardheid eerste voorkeur  \
# 0                                 -
# 1                                 -
# 2                 Hardheidsclausule
# 3                 Hardheidsclausule
# 4                                 -
#
#                                           Voorkeur 1  \
# 0                       Spinoza20first - v.a. vmbo-t
# 1                      Clusius College - v.a. vmbo-b
# 2                                 Alasca - v.a. havo
# 3                                 Alasca - v.a. havo
# 4  Metis Montessori Lyceum - Technasium havo/vwo ...
#
#                       Voorkeur 2  \
# 0                            NaN
# 1                            NaN
# 2  Fons Vitae Lyceum - v.a. havo
# 3               IVKO - v.a. havo
# 4             Alasca - v.a. havo
#
#                                           Voorkeur 3  \
# 0                                                NaN
# 1                                                NaN
# 2  Metis Montessori Lyceum - Technasium havo/vwo ...
# 3  Metis Montessori Lyceum - Coderclass of Metisp...
# 4                       Spinoza20first - v.a. vmbo-t
#
#                                           Voorkeur 4  \
# 0                                                NaN
# 1                                                NaN
# 2                     St. Nicolaaslyceum - v.a. havo
# 3                   Geert Groote College - v.a. havo
# 4  Metis Montessori Lyceum - Coderclass of Metisp...
#
#                                Voorkeur 5  ... Voorkeur 25 Voorkeur 26  \
# 0                                     NaN  ...         NaN         NaN
# 1                                     NaN  ...         NaN         NaN
# 2        Hervormd Lyceum Zuid - v.a. havo  ...         NaN         NaN
# 3  Berlage Lyceum - Tweetalig - v.a. havo  ...         NaN         NaN
# 4           Fons Vitae Lyceum - v.a. havo  ...         NaN         NaN
#
#   Voorkeur 27 Voorkeur 28 Voorkeur 29 Voorkeur 30 Voorkeur 31 Voorkeur 32  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Voorkeur 33 Voorkeur 34
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Simulating synthetic data - model $G_\alpha$

# %%
synthetic_df = model_alpha_synthetic_generator(choices_df, schools_df)

# %%
synthetic_df.sample(5)
# Out:
#      Basisschool advies                                 Voorkeur 1  \
# 7359        vmbo-t/havo         Geert Groote College - v.a. vmbo-t
# 5828             vmbo-k              Calvijn College - v.a. vmbo-b
# 3452                vwo                     Het 4e Gymnasium - vwo
# 4823           vmbo-b/k  Montessori Lyceum Oostpoort - v.a. vmbo-b
# 5488             vmbo-k   Hubertus & Berkhoff - Tweetalig - vmbo-k
#
#                                              Voorkeur 2  \
# 7359  Geert Groote College - Kansrijk HAVO - vmbo-t/...
# 5828                          IVKO - DAMU - v.a. vmbo-t
# 3452                                 Lumion - v.a. havo
# 4823                                                 NA
# 5488     St. Nicolaaslyceum - Tweetalig Onderwijs - vwo
#
#                                           Voorkeur 3  \
# 7359  Hervormd Lyceum West - Kansrijk VWO - havo/vwo
# 5828                         Vox College - v.a. havo
# 3452          Berlage Lyceum - Tweetalig - v.a. havo
# 4823                                              NA
# 5488                   CSB - Kansrijk VWO - havo/vwo
#
#                                              Voorkeur 4  \
# 7359  Bernard Nieuwentijt College (Monnickendam) - K...
# 5828  Bernard Nieuwentijt College (Monnickendam) - v...
# 3452                        Cburg College - v.a. vmbo-b
# 4823                                                 NA
# 5488                       Marcanti College - v.a. havo
#
#                       Voorkeur 5                    Voorkeur 6  \
# 7359        Spinoza Lyceum - vwo  Spinoza20first - v.a. vmbo-t
# 5828                          NA                            NA
# 3452  De nieuwe Havo - v.a. havo                 Over-Y - havo
# 4823                          NA                            NA
# 5488                          NA                            NA
#
#                         Voorkeur 7 Voorkeur 8 Voorkeur 9 Voorkeur 10  \
# 7359  IJburg College - v.a. vmbo-b         NA         NA          NA
# 5828                            NA         NA         NA          NA
# 3452                            NA         NA         NA          NA
# 4823                            NA         NA         NA          NA
# 5488                            NA         NA         NA          NA
#
#      Voorkeur 11 Voorkeur 12 Voorkeur 13 Voorkeur 14 Voorkeur 15 Voorkeur 16  \
# 7359          NA          NA          NA          NA          NA          NA
# 5828          NA          NA          NA          NA          NA          NA
# 3452          NA          NA          NA          NA          NA          NA
# 4823          NA          NA          NA          NA          NA          NA
# 5488          NA          NA          NA          NA          NA          NA
#
#      Voorkeur 17 Voorkeur 18 Voorkeur 19 Voorkeur 20 Voorkeur 21 Voorkeur 22
# 7359          NA          NA          NA          NA          NA          NA
# 5828          NA          NA          NA          NA          NA          NA
# 3452          NA          NA          NA          NA          NA          NA
# 4823          NA          NA          NA          NA          NA          NA
# 5488          NA          NA          NA          NA          NA          NA

# %%
synthetic_df.to_csv('synthetic_datasets/model_alpha_synthetic.csv')

# %% [markdown]
# ### Simulating synthetic data - Model $G_\beta$

# %%
synthetic_df2 = model_beta_synthetic_generator(choices_df, schools_df)
synthetic_df2.head()
# Out:
#   Basisschool advies                                  Voorkeur 1  \
# 0               havo               Fons Vitae Lyceum - v.a. havo
# 1               havo     Montessori Lyceum Amsterdam - v.a. havo
# 2               havo       Comenius Lyceum Amsterdam - v.a. havo
# 3               havo  Open Schoolgemeenschap Bijlmer - v.a. havo
# 4               havo              St. Nicolaaslyceum - v.a. havo
#
#                                           Voorkeur 2  \
# 0                       Cartesius Lyceum - v.a. havo
# 1                   Geert Groote College - v.a. havo
# 2  Metis Montessori Lyceum - Technasium havo/vwo ...
# 3                                   IVKO - v.a. havo
# 4                         Spinoza Lyceum - v.a. havo
#
#                                           Voorkeur 3  \
# 0                            Vox College - v.a. havo
# 1         Ir. Lely Lyceum - Technasium - v.a. vmbo-t
# 2  Metis Montessori Lyceum - Coderclass of Metisp...
# 3                         Vinse School - v.a. vmbo-t
# 4       Open Schoolgemeenschap Bijlmer - v.a. vmbo-t
#
#                          Voorkeur 4  \
# 0  Hervormd Lyceum Zuid - v.a. havo
# 1      Spinoza20first - v.a. vmbo-t
# 2           Havo de Hof - v.a. havo
# 3                Alasca - v.a. havo
# 4                Alasca - v.a. havo
#
#                                           Voorkeur 5  \
# 0            Montessori Lyceum Amsterdam - v.a. havo
# 1                        Cornelius Haga Lyceum - vwo
# 2                  Gerrit van der Veen College - vwo
# 3             Berlage Lyceum - Tweetalig - v.a. havo
# 4  Berlage Lyceum - Kansrijk VWO - Tweetalig - ha...
#
#                                    Voorkeur 6  \
# 0  Open Schoolgemeenschap Bijlmer - v.a. havo
# 1       Wellantcollege Linnaeus - v.a. vmbo-b
# 2     Montessori Lyceum Oostpoort - v.a. havo
# 3                  De nieuwe Havo - v.a. havo
# 4   Montessori Lyceum Oostpoort - v.a. vmbo-b
#
#                                           Voorkeur 7  \
# 0            Gerrit van der Veen College - v.a. havo
# 1            Spinoza Lyceum - Muziekplus - v.a. havo
# 2                            Vossius Gymnasium - vwo
# 3  Berlage Lyceum - Kansrijk VWO - Tweetalig - ha...
# 4                                  CSB - v.a. vmbo-t
#
#                                      Voorkeur 8  \
# 0       Spinoza Lyceum - Muziekplus - v.a. havo
# 1  Hervormd Lyceum West - Tweetalig - v.a. havo
# 2                 Clusius College - v.a. vmbo-b
# 3                St. Nicolaaslyceum - v.a. havo
# 4              Bindelmeer College - v.a. vmbo-b
#
#                            Voorkeur 9  \
# 0  Hervormd Lyceum West - v.a. vmbo-t
# 1                  Lumion - v.a. havo
# 2          Spinoza Lyceum - v.a. havo
# 3        Marcanti College - v.a. havo
# 4      Marcanti College - v.a. vmbo-t
#
#                                          Voorkeur 10  \
# 0                       Spinoza20first - v.a. vmbo-t
# 1                     St. Nicolaaslyceum - v.a. havo
# 2                         De nieuwe Havo - v.a. havo
# 3  Mediacollege Amsterdam - Kansrijk Kader - vmbo...
# 4            Comenius Lyceum Amsterdam - v.a. vmbo-t
#
#                                 Voorkeur 11                       Voorkeur 12  \
# 0                Spinoza Lyceum - v.a. havo    St. Nicolaaslyceum - v.a. havo
# 1                      Damstede - v.a. havo    Marcanti College - v.a. vmbo-b
# 2      Pieter Nieuwland College - v.a. havo         Marcanti College - vmbo-k
# 3  Hervormd Lyceum Zuid - Universalis - vwo  DENISE - Denise Havo - v.a. havo
# 4   Gerrit van der Veen College - v.a. havo          Panta Rhei - v.a. vmbo-b
#
#   Voorkeur 13 Voorkeur 14 Voorkeur 15 Voorkeur 16 Voorkeur 17 Voorkeur 18  \
# 0          NA          NA          NA          NA          NA          NA
# 1          NA          NA          NA          NA          NA          NA
# 2          NA          NA          NA          NA          NA          NA
# 3          NA          NA          NA          NA          NA          NA
# 4          NA          NA          NA          NA          NA          NA
#
#   Voorkeur 19 Voorkeur 20 Voorkeur 21 Voorkeur 22
# 0          NA          NA          NA          NA
# 1          NA          NA          NA          NA
# 2          NA          NA          NA          NA
# 3          NA          NA          NA          NA
# 4          NA          NA          NA          NA

# %%
synthetic_df2.to_csv('synthetic_datasets/model_beta_synthetic.csv')

# %% [markdown]
# ### Evaluation:

# %% [markdown]
# - No duplicate choice per student
# - Probability distribution close to real data
# - Distribution of number of choices students fill in
