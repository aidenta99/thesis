# %% [markdown]
# # Model $G_\alpha$

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
from model_alpha import model_alpha_synthetic_generator
from model_beta import model_beta_synthetic_generator

# %% [markdown]
# ### Load data

# %%
choices_df = pd.read_excel('data/2021.xlsx', sheet_name='Resultaten')
schools_df = pd.read_excel('data/2021.xlsx', sheet_name='Klassen')

# %%
choices_df.head()
# Out:
#   Basisschool advies  Lotnummer        Geplaatst op Positie  \
# 0        vmbo-t/havo       7389      Niet geplaatst       -
# 1             vmbo-b       7742      Niet geplaatst       -
# 2               havo        129  Alasca - v.a. havo       1
# 3           havo/vwo       7606  Alasca - v.a. havo       1
# 4           havo/vwo        109  Alasca - v.a. havo       2
#
#   Voorrang/Hardheid eerste voorkeur  \
# 0                                 -
# 1                                 -
# 2                 Hardheidsclausule
# 3                 Hardheidsclausule
# 4                                 -
#
#                                           Voorkeur 1  \
# 0                       Spinoza20first - v.a. vmbo-t
# 1                      Clusius College - v.a. vmbo-b
# 2                                 Alasca - v.a. havo
# 3                                 Alasca - v.a. havo
# 4  Metis Montessori Lyceum - Technasium havo/vwo ...
#
#                       Voorkeur 2  \
# 0                            NaN
# 1                            NaN
# 2  Fons Vitae Lyceum - v.a. havo
# 3               IVKO - v.a. havo
# 4             Alasca - v.a. havo
#
#                                           Voorkeur 3  \
# 0                                                NaN
# 1                                                NaN
# 2  Metis Montessori Lyceum - Technasium havo/vwo ...
# 3  Metis Montessori Lyceum - Coderclass of Metisp...
# 4                       Spinoza20first - v.a. vmbo-t
#
#                                           Voorkeur 4  \
# 0                                                NaN
# 1                                                NaN
# 2                     St. Nicolaaslyceum - v.a. havo
# 3                   Geert Groote College - v.a. havo
# 4  Metis Montessori Lyceum - Coderclass of Metisp...
#
#                                Voorkeur 5  ... Voorkeur 25 Voorkeur 26  \
# 0                                     NaN  ...         NaN         NaN
# 1                                     NaN  ...         NaN         NaN
# 2        Hervormd Lyceum Zuid - v.a. havo  ...         NaN         NaN
# 3  Berlage Lyceum - Tweetalig - v.a. havo  ...         NaN         NaN
# 4           Fons Vitae Lyceum - v.a. havo  ...         NaN         NaN
#
#   Voorkeur 27 Voorkeur 28 Voorkeur 29 Voorkeur 30 Voorkeur 31 Voorkeur 32  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Voorkeur 33 Voorkeur 34
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Simulating synthetic data - model $G_\alpha$

# %%
synthetic_df = model_alpha_synthetic_generator(choices_df, schools_df)

# %%
synthetic_df.head()
# Out:
#   Basisschool advies                                         Voorkeur 0  \
# 0               havo                      Fons Vitae Lyceum - v.a. havo
# 1               havo                         Vinse School - v.a. vmbo-t
# 2               havo                       Spinoza20first - v.a. vmbo-t
# 3               havo  Metis Montessori Lyceum - Coderclass of Metisp...
# 4               havo                      Ir. Lely Lyceum - v.a. vmbo-t
#
#                        Voorkeur 1                               Voorkeur 2  \
# 0              Alasca - v.a. havo     Pieter Nieuwland College - v.a. havo
# 1              Lumion - v.a. havo  Montessori Lyceum Amsterdam - v.a. havo
# 2  St. Nicolaaslyceum - v.a. havo    Pieter Nieuwland College - plus - vwo
# 3         Havo de Hof - v.a. havo               Spinoza Lyceum - v.a. havo
# 4            Xplore - v.a. vmbo-t               Hervormd Lyceum Zuid - vwo
#
#                                           Voorkeur 3  \
# 0             Berlage Lyceum - Tweetalig - v.a. havo
# 1                       Spinoza20first - v.a. vmbo-t
# 2                    Sweelinck College - v.a. vmbo-t
# 3  Berlage Lyceum - Kansrijk VWO - Tweetalig - ha...
# 4  Bernard Nieuwentijt College (Monnickendam) - v...
#
#                                           Voorkeur 4  \
# 0              Comenius Lyceum Amsterdam - v.a. havo
# 1                          Spring High - v.a. vmbo-t
# 2  Metis Montessori Lyceum - Technasium havo/vwo ...
# 3                   Geert Groote College - v.a. havo
# 4                            Calandlyceum - havo/vwo
#
#                                           Voorkeur 5  \
# 0            Gerrit van der Veen College - v.a. havo
# 1                                  CSB - v.a. vmbo-t
# 2     Bindelmeer College - Kansrijk Kader - vmbo-b/k
# 3  Pieter Nieuwland College - Kansrijk VWO - havo...
# 4                    Mediacollege Amsterdam - vmbo-k
#
#                                           Voorkeur 6  \
# 0                   Geert Groote College - v.a. havo
# 1  Ir. Lely Lyceum - Kansrijk VWO-Technasium - ha...
# 2              Comenius Lyceum Amsterdam - v.a. havo
# 3                       Spinoza20first - v.a. vmbo-t
# 4  Montessori Lyceum Amsterdam - Sluisbuurt - v.a...
#
#                               Voorkeur 7  \
# 0  Wellantcollege Linnaeus - v.a. vmbo-b
# 1       Hervormd Lyceum Zuid - v.a. havo
# 2                   Lumion - v.a. vmbo-t
# 3      Cornelius Haga Lyceum - v.a. havo
# 4             Geert Groote College - vwo
#
#                                 Voorkeur 8  ...  \
# 0             Cartesius Lyceum - v.a. havo  ...
# 1  Montessori Lyceum Oostpoort - v.a. havo  ...
# 2               De nieuwe Havo - v.a. havo  ...
# 3        Zuiderlicht College - v.a. vmbo-b  ...
# 4  Montessori Lyceum Oostpoort - v.a. havo  ...
#
#                                          Voorkeur 12  \
# 0                         SvPO Amsterdam - v.a. havo
# 1                                                 NA
# 2                                                 NA
# 3  Hervormd Lyceum West - Kansrijk HAVO - vmbo-t/...
# 4                            Fons Vitae Lyceum - vwo
#
#                                 Voorkeur 13  \
# 0                                        NA
# 1              IJburg College - v.a. vmbo-t
# 2                Bredero Mavo - v.a. vmbo-t
# 3  Spinoza Lyceum - Kansrijk VWO - havo/vwo
# 4         Hubertus & Berkhoff - v.a. vmbo-t
#
#                                          Voorkeur 14  \
# 0  Ir. Lely Lyceum - Kansrijk VWO-Technasium - ha...
# 1    Amsterdams Beroepscollege Noorderlicht - vmbo-k
# 2                                 IVKO - v.a. vmbo-t
# 3  Zuiderlicht College - Talentendansklas - v.a. ...
# 4         Calandlyceum - Kansrijk HAVO - vmbo-t/havo
#
#                                  Voorkeur 15  \
# 0          Zuiderlicht College - v.a. vmbo-b
# 1          Gerrit van der Veen College - vwo
# 2                     Cygnus gymnasium - vwo
# 3  Montessori Lyceum Amsterdam - v.a. vmbo-t
# 4                     Cygnus gymnasium - vwo
#
#                                       Voorkeur 16  \
# 0  Montessori Lyceum Amsterdam - Sluisbuurt - vwo
# 1                         Mundus College - vmbo-t
# 2       Montessori Lyceum Amsterdam - v.a. vmbo-t
# 3  Metis Montessori Lyceum - Technasium vwo - vwo
# 4                       IVKO - DAMU - v.a. vmbo-t
#
#                                          Voorkeur 17  \
# 0  Montessori Lyceum Amsterdam - Sluisbuurt - v.a...
# 1                Cornelius Haga Lyceum - v.a. vmbo-t
# 2        Clusius College - Kansrijk Kader - vmbo-b/k
# 3                                  Vox College - vwo
# 4             Calandlyceum - Kansrijk VWO - havo/vwo
#
#                                  Voorkeur 18  \
# 0                         IVKO - v.a. vmbo-t
# 1  Ir. Lely Lyceum - Kansrijk VWO - havo/vwo
# 2           Bindelmeer College - v.a. vmbo-b
# 3                    Mundus College - vmbo-k
# 4                   Barlaeus Gymnasium - vwo
#
#                                          Voorkeur 19  \
# 0          Ir. Lely Lyceum - Kansrijk VWO - havo/vwo
# 1                     Wellantcollege Sloten - vmbo-t
# 2    Zuiderlicht College - Kansrijk Kader - vmbo-b/k
# 3                            Fons Vitae Lyceum - vwo
# 4  Geert Groote College - Kansrijk HAVO - vmbo-t/...
#
#                                          Voorkeur 20  \
# 0  Geert Groote College - Kansrijk HAVO - vmbo-t/...
# 1                  Cornelius Haga Lyceum - v.a. havo
# 2  College De Meer - Kansrijk HAVO (icm Havo de H...
# 3                             Het 4e Gymnasium - vwo
# 4           Berlage Lyceum - Tweetalig - v.a. vmbo-t
#
#                                          Voorkeur 21
# 0     Metis Montessori Lyceum - Technasium vwo - vwo
# 1               Open Schoolgemeenschap Bijlmer - vwo
# 2  Pieter Nieuwland College - Kansrijk VWO - havo...
# 3                  Montessori Lyceum Amsterdam - vwo
# 4                         Calandlyceum - vmbo-t/havo
#
# [5 rows x 23 columns]

# %%
synthetic_df.to_csv('synthetic_datasets/model_alpha_synthetic.csv')

# %%
### Simulating

# %% [markdown]
# ### Evaluation:

# %% [markdown]
# - No duplicate choice per student
# - Probability distribution close to real data
# - Distribution of number of choices students fill in
